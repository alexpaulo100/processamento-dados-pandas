# %% [markdown]
# <a href="https://colab.research.google.com/github/alexpaulo100/processamento-dados-pandas/blob/main/Manipulacao_dados_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel('/content/drive/MyDrive/ETL-pandas/01-21.xlsx')

# %%
df1
# Out:
#                           Data 2021-01-31 00:00:00   Unnamed: 2  \
# 0                          NaN                 NaN          NaN
# 1                      Produto                Lote  País Origem
# 2      Produto H - Marca Delta           Lote 8191           CH
# 3     Produto B - Marca Lambda           Lote 7447           CH
# 4       Produto H - Marca Gama           Lote 7129           BR
# ..                         ...                 ...          ...
# 273     Produto M - Marca Gama           Lote 3647           US
# 274   Produto B - Marca Lambda           Lote 3175           CH
# 275                        NaN                 NaN          NaN
# 276  Produto R - Marca Épsilon           Lote 4962           CH
# 277     Produto J - Marca Alfa           Lote 5853           BR
#
#                                             Unnamed: 3   Unnamed: 4  \
# 0                                                  NaN          NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Data                 244 non-null    object
#  1   2021-01-31 00:00:00  244 non-null    object
#  2   Unnamed: 2           244 non-null    object
#  3   Unnamed: 3           244 non-null    object
#  4   Unnamed: 4           244 non-null    object
#  5   Unnamed: 5           244 non-null    object
#  6   Unnamed: 6           244 non-null    object
# dtypes: object(7)
# memory usage: 15.3+ KB

# %%
df1.shape
# Out:
# (278, 7)

# %%
df1.head()
# Out:
#                        Data 2021-01-31 00:00:00   Unnamed: 2  \
# 0                       NaN                 NaN          NaN
# 1                   Produto                Lote  País Origem
# 2   Produto H - Marca Delta           Lote 8191           CH
# 3  Produto B - Marca Lambda           Lote 7447           CH
# 4    Produto H - Marca Gama           Lote 7129           BR
#
#                                           Unnamed: 3   Unnamed: 4  \
# 0                                                NaN          NaN
# 1                                           Endereço  Qtd Estoque
# 2                        Nanquim 123 - Xangai, China      6071.00
# 3                   Wangfujing 12456 - Pequim, China      5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...      1184.00
#
#        Unnamed: 5           Unnamed: 6
# 0             NaN                  NaN
# 1  Valor Unitário             Validade
# 2            3.64  2026-06-13 00:00:00
# ...

# %%
# Exclui as linhas em que todos os valores estão vazios
df1 = df1.dropna(how="all", axis = 0)

# %%
df1
# Out:
#                           Data 2021-01-31 00:00:00   Unnamed: 2  \
# 1                      Produto                Lote  País Origem
# 2      Produto H - Marca Delta           Lote 8191           CH
# 3     Produto B - Marca Lambda           Lote 7447           CH
# 4       Produto H - Marca Gama           Lote 7129           BR
# 5       Produto C - Marca Gama           Lote 5155           AR
# ..                         ...                 ...          ...
# 272  Produto E - Marca Épsilon           Lote 1371           BR
# 273     Produto M - Marca Gama           Lote 3647           US
# 274   Produto B - Marca Lambda           Lote 3175           CH
# 276  Produto R - Marca Épsilon           Lote 4962           CH
# 277     Produto J - Marca Alfa           Lote 5853           BR
#
#                                             Unnamed: 3   Unnamed: 4  \
# 1                                             Endereço  Qtd Estoque
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (244, 7)

# %%
df1.head(10)
# Out:
#                         Data 2021-01-31 00:00:00   Unnamed: 2  \
# 1                    Produto                Lote  País Origem
# 2    Produto H - Marca Delta           Lote 8191           CH
# 3   Produto B - Marca Lambda           Lote 7447           CH
# 4     Produto H - Marca Gama           Lote 7129           BR
# 5     Produto C - Marca Gama           Lote 5155           AR
# 7     Produto H - Marca Alfa           Lote 3667           BR
# 8     Produto H - Marca Capa           Lote 4451           BR
# 9     Produto R - Marca Gama           Lote 3338           AR
# 10    Produto R - Marca Alfa           Lote 6092           BR
# 11   Produto O - Marca Delta           Lote 2044           AR
#
#                                            Unnamed: 3   Unnamed: 4  \
# 1                                            Endereço  Qtd Estoque
# 2                         Nanquim 123 - Xangai, China      6071.00
# 3                    Wangfujing 12456 - Pequim, China      5557.00
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 1 to 277
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Data                 244 non-null    object
#  1   2021-01-31 00:00:00  244 non-null    object
#  2   Unnamed: 2           244 non-null    object
#  3   Unnamed: 3           244 non-null    object
#  4   Unnamed: 4           244 non-null    object
#  5   Unnamed: 5           244 non-null    object
#  6   Unnamed: 6           244 non-null    object
# dtypes: object(7)
# memory usage: 15.2+ KB

# %%
df1.dtypes.value_counts()
# Out:
# object    7
# dtype: int64

# %%
df1.columns
# Out:
# Index([             'Data', 2021-01-31 00:00:00,        'Unnamed: 2',
#               'Unnamed: 3',        'Unnamed: 4',        'Unnamed: 5',
#               'Unnamed: 6'],
#       dtype='object')

# %%
df1.head()
# Out:
#                        Data 2021-01-31 00:00:00   Unnamed: 2  \
# 1                   Produto                Lote  País Origem
# 2   Produto H - Marca Delta           Lote 8191           CH
# 3  Produto B - Marca Lambda           Lote 7447           CH
# 4    Produto H - Marca Gama           Lote 7129           BR
# 5    Produto C - Marca Gama           Lote 5155           AR
#
#                                           Unnamed: 3   Unnamed: 4  \
# 1                                           Endereço  Qtd Estoque
# 2                        Nanquim 123 - Xangai, China      6071.00
# 3                   Wangfujing 12456 - Pequim, China      5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...      1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina      5974.00
#
#        Unnamed: 5           Unnamed: 6
# 1  Valor Unitário             Validade
# 2            3.64  2026-06-13 00:00:00
# 3            9.24  2025-01-02 00:00:00
# ...

# %%
# Transformando as colunas indices
df1.columns = ['Produto', 'Lote','Pais Origem', 'Endereço', 'Qtd Estoque', 'Valor Unitário', 'Validade']

# %%
df1
# Out:
#                        Produto       Lote  Pais Origem  \
# 1                      Produto       Lote  País Origem
# 2      Produto H - Marca Delta  Lote 8191           CH
# 3     Produto B - Marca Lambda  Lote 7447           CH
# 4       Produto H - Marca Gama  Lote 7129           BR
# 5       Produto C - Marca Gama  Lote 5155           AR
# ..                         ...        ...          ...
# 272  Produto E - Marca Épsilon  Lote 1371           BR
# 273     Produto M - Marca Gama  Lote 3647           US
# 274   Produto B - Marca Lambda  Lote 3175           CH
# 276  Produto R - Marca Épsilon  Lote 4962           CH
# 277     Produto J - Marca Alfa  Lote 5853           BR
#
#                                               Endereço  Qtd Estoque  \
# 1                                             Endereço  Qtd Estoque
# 2                          Nanquim 123 - Xangai, China      6071.00
# 3                     Wangfujing 12456 - Pequim, China      5557.00
# ...

# %%
# Excluindo linha
df1 = df1.drop(labels=1,axis=0)

# %%
df1
# Out:
#                        Produto       Lote Pais Origem  \
# 2      Produto H - Marca Delta  Lote 8191          CH
# 3     Produto B - Marca Lambda  Lote 7447          CH
# 4       Produto H - Marca Gama  Lote 7129          BR
# 5       Produto C - Marca Gama  Lote 5155          AR
# 7       Produto H - Marca Alfa  Lote 3667          BR
# ..                         ...        ...         ...
# 272  Produto E - Marca Épsilon  Lote 1371          BR
# 273     Produto M - Marca Gama  Lote 3647          US
# 274   Produto B - Marca Lambda  Lote 3175          CH
# 276  Produto R - Marca Épsilon  Lote 4962          CH
# 277     Produto J - Marca Alfa  Lote 5853          BR
#
#                                               Endereço Qtd Estoque  \
# 2                          Nanquim 123 - Xangai, China     6071.00
# 3                     Wangfujing 12456 - Pequim, China     5557.00
# 4    Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# ...

# %%
df1.insert(0, column = 'ID', value = range(1, 1 + len(df1)))

# %%
df1.head()
# Out:
#    ID                   Produto       Lote Pais Origem  \
# 2   1   Produto H - Marca Delta  Lote 8191          CH
# 3   2  Produto B - Marca Lambda  Lote 7447          CH
# 4   3    Produto H - Marca Gama  Lote 7129          BR
# 5   4    Produto C - Marca Gama  Lote 5155          AR
# 7   5    Produto H - Marca Alfa  Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade
# 2           3.64  2026-06-13 00:00:00
# 3           9.24  2025-01-02 00:00:00
# 4           2.48  2026-08-11 00:00:00
# 5           9.02  2024-12-23 00:00:00
# 7           3.16  2027-02-07 00:00:00

# %%
df1.columns
# Out:
# Index(['ID', 'Produto', 'Lote', 'Pais Origem', 'Endereço', 'Qtd Estoque',
#        'Valor Unitário', 'Validade'],
#       dtype='object')

# %%
df1
# Out:
#       ID                    Produto       Lote Pais Origem  \
# 2      1    Produto H - Marca Delta  Lote 8191          CH
# 3      2   Produto B - Marca Lambda  Lote 7447          CH
# 4      3     Produto H - Marca Gama  Lote 7129          BR
# 5      4     Produto C - Marca Gama  Lote 5155          AR
# 7      5     Produto H - Marca Alfa  Lote 3667          BR
# ..   ...                        ...        ...         ...
# 272  239  Produto E - Marca Épsilon  Lote 1371          BR
# 273  240     Produto M - Marca Gama  Lote 3647          US
# 274  241   Produto B - Marca Lambda  Lote 3175          CH
# 276  242  Produto R - Marca Épsilon  Lote 4962          CH
# 277  243     Produto J - Marca Alfa  Lote 5853          BR
#
#                                               Endereço Qtd Estoque  \
# 2                          Nanquim 123 - Xangai, China     6071.00
# 3                     Wangfujing 12456 - Pequim, China     5557.00
# ...

# %%
df1['Produto']
# Out:
# 2        Produto H - Marca Delta
# 3       Produto B - Marca Lambda
# 4         Produto H - Marca Gama
# 5         Produto C - Marca Gama
# 7         Produto H - Marca Alfa
#                  ...
# 272    Produto E - Marca Épsilon
# 273       Produto M - Marca Gama
# 274     Produto B - Marca Lambda
# 276    Produto R - Marca Épsilon
# 277       Produto J - Marca Alfa
# Name: Produto, Length: 243, dtype: object

# %%
df = df1.copy()

# %%
df1.head()
# Out:
#    ID                   Produto       Lote Pais Origem  \
# 2   1   Produto H - Marca Delta  Lote 8191          CH
# 3   2  Produto B - Marca Lambda  Lote 7447          CH
# 4   3    Produto H - Marca Gama  Lote 7129          BR
# 5   4    Produto C - Marca Gama  Lote 5155          AR
# 7   5    Produto H - Marca Alfa  Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade
# 2           3.64  2026-06-13 00:00:00
# 3           9.24  2025-01-02 00:00:00
# 4           2.48  2026-08-11 00:00:00
# 5           9.02  2024-12-23 00:00:00
# 7           3.16  2027-02-07 00:00:00

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 2 to 277
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              243 non-null    int64
#  1   Produto         243 non-null    object
#  2   Lote            243 non-null    object
#  3   Pais Origem     243 non-null    object
#  4   Endereço        243 non-null    object
#  5   Qtd Estoque     243 non-null    object
#  6   Valor Unitário  243 non-null    object
#  7   Validade        243 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 17.1+ KB

# %%
if isinstance(df1, pd.DataFrame):
    print('O objeto é um DataFrame')
else:
    print('O objeto não é um DataFrame')
# Out:
# O objeto é um DataFrame

# %%
df1.columns
# Out:
# Index(['ID', 'Produto', 'Lote', 'Pais Origem', 'Endereço', 'Qtd Estoque',
#        'Valor Unitário', 'Validade'],
#       dtype='object')

# %%
# Divindo a coluna produto em produto e marca
df1[['Produto', 'Marca']] = df1['Produto'].str.split('-', expand = True)

# %%
df1.head()
# Out:
#    ID     Produto       Lote Pais Origem  \
# 2   1  Produto H   Lote 8191          CH
# 3   2  Produto B   Lote 7447          CH
# 4   3  Produto H   Lote 7129          BR
# 5   4  Produto C   Lote 5155          AR
# 7   5  Produto H   Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade          Marca
# 2           3.64  2026-06-13 00:00:00    Marca Delta
# 3           9.24  2025-01-02 00:00:00   Marca Lambda
# 4           2.48  2026-08-11 00:00:00     Marca Gama
# 5           9.02  2024-12-23 00:00:00     Marca Gama
# 7           3.16  2027-02-07 00:00:00     Marca Alfa

# %%
df1.columns
# Out:
# Index(['ID', 'Produto', 'Lote', 'Pais Origem', 'Endereço', 'Qtd Estoque',
#        'Valor Unitário', 'Validade', 'Marca'],
#       dtype='object')

# %%
df1.head()
# Out:
#    ID     Produto       Lote Pais Origem  \
# 2   1  Produto H   Lote 8191          CH
# 3   2  Produto B   Lote 7447          CH
# 4   3  Produto H   Lote 7129          BR
# 5   4  Produto C   Lote 5155          AR
# 7   5  Produto H   Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade          Marca
# 2           3.64  2026-06-13 00:00:00    Marca Delta
# 3           9.24  2025-01-02 00:00:00   Marca Lambda
# 4           2.48  2026-08-11 00:00:00     Marca Gama
# 5           9.02  2024-12-23 00:00:00     Marca Gama
# 7           3.16  2027-02-07 00:00:00     Marca Alfa

# %%
display(df1.head())
# Out:
#    ID     Produto       Lote Pais Origem  \
# 2   1  Produto H   Lote 8191          CH
# 3   2  Produto B   Lote 7447          CH
# 4   3  Produto H   Lote 7129          BR
# 5   4  Produto C   Lote 5155          AR
# 7   5  Produto H   Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade          Marca
# 2           3.64  2026-06-13 00:00:00    Marca Delta
# 3           9.24  2025-01-02 00:00:00   Marca Lambda
# 4           2.48  2026-08-11 00:00:00     Marca Gama
# 5           9.02  2024-12-23 00:00:00     Marca Gama
# 7           3.16  2027-02-07 00:00:00     Marca Alfa

# %%
# Alterando a posição da coluna marca
df1 = df1.reindex(columns=['ID', 'Produto', 'Marca', 'Lote', 'Pais Origem', 'Endereço', 'Qtd Estoque', 'Valor Unitário', 'Validade'])

# %%
df1.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 2   1  Produto H     Marca Delta  Lote 8191          CH
# 3   2  Produto B    Marca Lambda  Lote 7447          CH
# 4   3  Produto H      Marca Gama  Lote 7129          BR
# 5   4  Produto C      Marca Gama  Lote 5155          AR
# 7   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade
# 2           3.64  2026-06-13 00:00:00
# 3           9.24  2025-01-02 00:00:00
# 4           2.48  2026-08-11 00:00:00
# 5           9.02  2024-12-23 00:00:00
# 7           3.16  2027-02-07 00:00:00

# %%
df = df1.copy()

# %%
df.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 2   1  Produto H     Marca Delta  Lote 8191          CH
# 3   2  Produto B    Marca Lambda  Lote 7447          CH
# 4   3  Produto H      Marca Gama  Lote 7129          BR
# 5   4  Produto C      Marca Gama  Lote 5155          AR
# 7   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade
# 2           3.64  2026-06-13 00:00:00
# 3           9.24  2025-01-02 00:00:00
# 4           2.48  2026-08-11 00:00:00
# 5           9.02  2024-12-23 00:00:00
# 7           3.16  2027-02-07 00:00:00

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 2 to 277
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              243 non-null    int64
#  1   Produto         243 non-null    object
#  2   Marca           243 non-null    object
#  3   Lote            243 non-null    object
#  4   Pais Origem     243 non-null    object
#  5   Endereço        243 non-null    object
#  6   Qtd Estoque     243 non-null    object
#  7   Valor Unitário  243 non-null    object
#  8   Validade        243 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 19.0+ KB

# %%
# Salvando o arquivo em formato excel(salvo com sucesso)
df1.to_excel("tratadoparcial2_28-03-2023.xlsx",index=False)

# %%
df.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 2   1  Produto H     Marca Delta  Lote 8191          CH
# 3   2  Produto B    Marca Lambda  Lote 7447          CH
# 4   3  Produto H      Marca Gama  Lote 7129          BR
# 5   4  Produto C      Marca Gama  Lote 5155          AR
# 7   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China     6071.00
# 3                   Wangfujing 12456 - Pequim, China     5557.00
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     1184.00
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     5974.00
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...     3014.00
#
#   Valor Unitário             Validade
# 2           3.64  2026-06-13 00:00:00
# 3           9.24  2025-01-02 00:00:00
# 4           2.48  2026-08-11 00:00:00
# 5           9.02  2024-12-23 00:00:00
# 7           3.16  2027-02-07 00:00:00

# %%
# Transformando em float
df1['Valor Unitário'] = pd.to_numeric(df1['Valor Unitário'], errors='coerce')
df1['Qtd Estoque'] = pd.to_numeric(df1['Qtd Estoque'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 2 to 277
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              243 non-null    int64
#  1   Produto         243 non-null    object
#  2   Marca           243 non-null    object
#  3   Lote            243 non-null    object
#  4   Pais Origem     243 non-null    object
#  5   Endereço        243 non-null    object
#  6   Qtd Estoque     243 non-null    float64
#  7   Valor Unitário  243 non-null    float64
#  8   Validade        243 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 19.0+ KB

# %%
# Criando nova coluna "Cidade" extraindo da coluna "Endereço " somente o nome da cidade
df1['Cidade'] = df1['Endereço'].str.split('-').str[1].str.split(',').str[0]

# %%
df1.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 2   1  Produto H     Marca Delta  Lote 8191          CH
# 3   2  Produto B    Marca Lambda  Lote 7447          CH
# 4   3  Produto H      Marca Gama  Lote 7129          BR
# 5   4  Produto C      Marca Gama  Lote 5155          AR
# 7   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço  Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China       6071.0
# 3                   Wangfujing 12456 - Pequim, China       5557.0
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...       1184.0
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina       5974.0
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...       3014.0
#
#    Valor Unitário             Validade      Cidade
# 2            3.64  2026-06-13 00:00:00      Xangai
# 3            9.24  2025-01-02 00:00:00      Pequim
# 4            2.48  2026-08-11 00:00:00   São Paulo
# ...

# %%
# Reordenando as colunas
df1 = df1.reindex(columns=['ID', 'Produto', 'Marca', 'Lote', 'Pais Origem', 'Endereço', 'Cidade','Qtd Estoque', 'Valor Unitário', 'Validade'])

# %%
df1.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 2   1  Produto H     Marca Delta  Lote 8191          CH
# 3   2  Produto B    Marca Lambda  Lote 7447          CH
# 4   3  Produto H      Marca Gama  Lote 7129          BR
# 5   4  Produto C      Marca Gama  Lote 5155          AR
# 7   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço      Cidade  Qtd Estoque  \
# 2                        Nanquim 123 - Xangai, China      Xangai       6071.0
# 3                   Wangfujing 12456 - Pequim, China      Pequim       5557.0
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo       1184.0
# 5      Marcelo T. de Alvear 120 - Cordoba, Argentina     Cordoba       5974.0
# 7  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo       3014.0
#
#    Valor Unitário             Validade
# 2            3.64  2026-06-13 00:00:00
# 3            9.24  2025-01-02 00:00:00
# ...

# %%
# Salvando o arquivo em formato excel(salvo com sucesso)
df1.to_excel("tratadoparcial3_28-03-2023.xlsx",index=False)
print(f"O arquivo '{df1}' foi salvo com sucesso!")
# Out:
# O arquivo '      ID     Produto           Marca       Lote Pais Origem  \
# 2      1  Produto H      Marca Delta  Lote 8191          CH
# 3      2  Produto B     Marca Lambda  Lote 7447          CH
# 4      3  Produto H       Marca Gama  Lote 7129          BR
# 5      4  Produto C       Marca Gama  Lote 5155          AR
# 7      5  Produto H       Marca Alfa  Lote 3667          BR
# ..   ...         ...             ...        ...         ...
# 272  239  Produto E    Marca Épsilon  Lote 1371          BR
# 273  240  Produto M       Marca Gama  Lote 3647          US
# 274  241  Produto B     Marca Lambda  Lote 3175          CH
# 276  242  Produto R    Marca Épsilon  Lote 4962          CH
# 277  243  Produto J       Marca Alfa  Lote 5853          BR
#
#                                               Endereço      Cidade  \
# 2                          Nanquim 123 - Xangai, China      Xangai
# 3                     Wangfujing 12456 - Pequim, China      Pequim
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 2 to 277
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              243 non-null    int64
#  1   Produto         243 non-null    object
#  2   Marca           243 non-null    object
#  3   Lote            243 non-null    object
#  4   Pais Origem     243 non-null    object
#  5   Endereço        243 non-null    object
#  6   Cidade          243 non-null    object
#  7   Qtd Estoque     243 non-null    float64
#  8   Valor Unitário  243 non-null    float64
#  9   Validade        243 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 20.9+ KB

# %%
# Criando nova coluna no local desejado com os valores multiplicados
df1.insert(9, column = 'Valor Total', value = df1['Qtd Estoque'] * df1['Valor Unitário'])

# %%
# Salvando o arquivo em formato excel(salvo com sucesso)
df1.to_excel("tratadoparcial4_28-03-2023.xlsx",index=False)
print(f"O arquivo '{df1}' foi salvo com sucesso!")
# Out:
# O arquivo '      ID     Produto           Marca       Lote Pais Origem  \
# 2      1  Produto H      Marca Delta  Lote 8191          CH
# 3      2  Produto B     Marca Lambda  Lote 7447          CH
# 4      3  Produto H       Marca Gama  Lote 7129          BR
# 5      4  Produto C       Marca Gama  Lote 5155          AR
# 7      5  Produto H       Marca Alfa  Lote 3667          BR
# ..   ...         ...             ...        ...         ...
# 272  239  Produto E    Marca Épsilon  Lote 1371          BR
# 273  240  Produto M       Marca Gama  Lote 3647          US
# 274  241  Produto B     Marca Lambda  Lote 3175          CH
# 276  242  Produto R    Marca Épsilon  Lote 4962          CH
# 277  243  Produto J       Marca Alfa  Lote 5853          BR
#
#                                               Endereço      Cidade  \
# 2                          Nanquim 123 - Xangai, China      Xangai
# 3                     Wangfujing 12456 - Pequim, China      Pequim
# ...

# %%
df2 = pd.read_excel('/content/tratadoparcial4_28-03-2023.xlsx')

# %%
df2.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 0   1  Produto H     Marca Delta  Lote 8191          CH
# 1   2  Produto B    Marca Lambda  Lote 7447          CH
# 2   3  Produto H      Marca Gama  Lote 7129          BR
# 3   4  Produto C      Marca Gama  Lote 5155          AR
# 4   5  Produto H      Marca Alfa  Lote 3667          BR
#
#                                             Endereço      Cidade  Qtd Estoque  \
# 0                        Nanquim 123 - Xangai, China      Xangai         6071
# 1                   Wangfujing 12456 - Pequim, China      Pequim         5557
# 2  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo         1184
# 3      Marcelo T. de Alvear 120 - Cordoba, Argentina     Cordoba         5974
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo         3014
#
#    Valor Unitário  Valor Total   Validade
# 0            3.64     22098.44 2026-06-13
# 1            9.24     51346.68 2025-01-02
# ...

# %%
# Alterando as siglas CH, BR, para Brasil e China - metodo replace
#df1['Pais_Origem'] = df1['Pais_Origem'].replace({'CH':'China','BR':'Brasil', 'AR':'Argentina','US':'Estados Unidos'})

# %%
df2.columns
# Out:
# Index(['ID', 'Produto', 'Marca', 'Lote', 'Pais Origem', 'Endereço', 'Cidade',
#        'Qtd Estoque', 'Valor Unitário', 'Valor Total', 'Validade'],
#       dtype='object')

# %%
# Alterando as siglas CH, BR, para Brasil e China - metodo replace
paises = {"CH": "China", "AR": "Argentina", "BR": "Brasil", "US": "Estados Unidos"}
df2["Pais Origem"] = df2["Pais Origem"].replace(paises)

# %%
df2
# Out:
#       ID     Produto           Marca       Lote     Pais Origem  \
# 0      1  Produto H      Marca Delta  Lote 8191           China
# 1      2  Produto B     Marca Lambda  Lote 7447           China
# 2      3  Produto H       Marca Gama  Lote 7129          Brasil
# 3      4  Produto C       Marca Gama  Lote 5155       Argentina
# 4      5  Produto H       Marca Alfa  Lote 3667          Brasil
# ..   ...         ...             ...        ...             ...
# 238  239  Produto E    Marca Épsilon  Lote 1371          Brasil
# 239  240  Produto M       Marca Gama  Lote 3647  Estados Unidos
# 240  241  Produto B     Marca Lambda  Lote 3175           China
# 241  242  Produto R    Marca Épsilon  Lote 4962           China
# 242  243  Produto J       Marca Alfa  Lote 5853          Brasil
#
#                                               Endereço      Cidade  \
# 0                          Nanquim 123 - Xangai, China      Xangai
# ...

# %%
df2.columns
# Out:
# Index(['ID', 'Produto', 'Marca', 'Lote', 'Pais Origem', 'Endereço', 'Cidade',
#        'Qtd Estoque', 'Valor Unitário', 'Valor Total', 'Validade'],
#       dtype='object')

# %%
df2['Pais Origem']
# Out:
# 0               China
# 1               China
# 2              Brasil
# 3           Argentina
# 4              Brasil
#             ...
# 238            Brasil
# 239    Estados Unidos
# 240             China
# 241             China
# 242            Brasil
# Name: Pais Origem, Length: 243, dtype: object

# %%
# Salvando o arquivo em formato excel(salvo com sucesso)
df2.to_excel("tratadoparcial7_28-03-2023.xlsx",index=False)
print(f"O arquivo '{df2}' foi salvo com sucesso!")
# Out:
# O arquivo '      ID     Produto           Marca       Lote     Pais Origem  \
# 0      1  Produto H      Marca Delta  Lote 8191           China
# 1      2  Produto B     Marca Lambda  Lote 7447           China
# 2      3  Produto H       Marca Gama  Lote 7129          Brasil
# 3      4  Produto C       Marca Gama  Lote 5155       Argentina
# 4      5  Produto H       Marca Alfa  Lote 3667          Brasil
# ..   ...         ...             ...        ...             ...
# 238  239  Produto E    Marca Épsilon  Lote 1371          Brasil
# 239  240  Produto M       Marca Gama  Lote 3647  Estados Unidos
# 240  241  Produto B     Marca Lambda  Lote 3175           China
# 241  242  Produto R    Marca Épsilon  Lote 4962           China
# 242  243  Produto J       Marca Alfa  Lote 5853          Brasil
#
#                                               Endereço      Cidade  \
# 0                          Nanquim 123 - Xangai, China      Xangai
# ...

# %%
# Importando a biblioteca datetime
from datetime import datetime, date

# %%
# Calculando a diferença da data atual com a data de validade e criando nova coluna Dias de Validade
data_atual = datetime.today()
df2['Dias de Validade'] = (df2['Validade']- data_atual).dt.days

# %%
df2.head()
# Out:
#    ID     Produto          Marca       Lote Pais Origem  \
# 0   1  Produto H     Marca Delta  Lote 8191       China
# 1   2  Produto B    Marca Lambda  Lote 7447       China
# 2   3  Produto H      Marca Gama  Lote 7129      Brasil
# 3   4  Produto C      Marca Gama  Lote 5155   Argentina
# 4   5  Produto H      Marca Alfa  Lote 3667      Brasil
#
#                                             Endereço      Cidade  Qtd Estoque  \
# 0                        Nanquim 123 - Xangai, China      Xangai         6071
# 1                   Wangfujing 12456 - Pequim, China      Pequim         5557
# 2  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo         1184
# 3      Marcelo T. de Alvear 120 - Cordoba, Argentina     Cordoba         5974
# 4  Rua Líbero Badaró, 425. Bairro Sé - São Paulo,...   São Paulo         3014
#
#    Valor Unitário  Valor Total   Validade  Dias de Validade
# 0            3.64     22098.44 2026-06-13              1172
# ...

# %%
# Verificando o type da coluna Validade
df2.dtypes
# Out:
# ID                           int64
# Produto                     object
# Marca                       object
# Lote                        object
# Pais Origem                 object
# Endereço                    object
# Cidade                      object
# Qtd Estoque                  int64
# Valor Unitário             float64
# Valor Total                float64
# Validade            datetime64[ns]
# Dias de Validade             int64
# dtype: object

# %%
# Salvando o arquivo em formato excel(salvo com sucesso)
df2.to_excel("dataset-tratado-final_28-03-2023.xlsx",index=False)
print(f"O arquivo '{df2}' foi salvo com sucesso!")
# Out:
# O arquivo '      ID     Produto           Marca       Lote     Pais Origem  \
# 0      1  Produto H      Marca Delta  Lote 8191           China
# 1      2  Produto B     Marca Lambda  Lote 7447           China
# 2      3  Produto H       Marca Gama  Lote 7129          Brasil
# 3      4  Produto C       Marca Gama  Lote 5155       Argentina
# 4      5  Produto H       Marca Alfa  Lote 3667          Brasil
# ..   ...         ...             ...        ...             ...
# 238  239  Produto E    Marca Épsilon  Lote 1371          Brasil
# 239  240  Produto M       Marca Gama  Lote 3647  Estados Unidos
# 240  241  Produto B     Marca Lambda  Lote 3175           China
# 241  242  Produto R    Marca Épsilon  Lote 4962           China
# 242  243  Produto J       Marca Alfa  Lote 5853          Brasil
#
#                                               Endereço      Cidade  \
# 0                          Nanquim 123 - Xangai, China      Xangai
# ...

# %%
# Finalizando
df2
# Out:
#       ID     Produto           Marca       Lote     Pais Origem  \
# 0      1  Produto H      Marca Delta  Lote 8191           China
# 1      2  Produto B     Marca Lambda  Lote 7447           China
# 2      3  Produto H       Marca Gama  Lote 7129          Brasil
# 3      4  Produto C       Marca Gama  Lote 5155       Argentina
# 4      5  Produto H       Marca Alfa  Lote 3667          Brasil
# ..   ...         ...             ...        ...             ...
# 238  239  Produto E    Marca Épsilon  Lote 1371          Brasil
# 239  240  Produto M       Marca Gama  Lote 3647  Estados Unidos
# 240  241  Produto B     Marca Lambda  Lote 3175           China
# 241  242  Produto R    Marca Épsilon  Lote 4962           China
# 242  243  Produto J       Marca Alfa  Lote 5853          Brasil
#
#                                               Endereço      Cidade  \
# 0                          Nanquim 123 - Xangai, China      Xangai
# ...
